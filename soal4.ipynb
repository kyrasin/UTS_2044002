# %%
import pandas as pd
df = pd.read_csv('Salary_Data.csv')

# %%
df.head()
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %%
a=df["YearsExperience"]
b=df["Salary"]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.scatter(a, b)

# %%
from sklearn.linear_model import LinearRegression

#latih model dengan linear regression.fit()
a = a.values.reshape(-1,1)
linreg=LinearRegression()
linreg.fit(a,b)

LinearRegression()
# Out:
# LinearRegression()

# %%
plt.scatter(a, b)
plt.plot(a, linreg.predict(a))
